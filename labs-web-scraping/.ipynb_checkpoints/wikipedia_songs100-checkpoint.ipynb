# %% [markdown]
# # Expand the project

# %% [markdown]
# Find other lists of hot songs on the internet and scrape them aswell

# %%
# import libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd
import requests
import math

# %%
# download html with a get request
r = requests.get('https://de.wikipedia.org/wiki/Die_500_besten_Songs_aller_Zeiten_(Rolling_Stone)')
r.status_code
# Out:
# 200

# %%
html = r.content
html
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="de" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Die 500 besten Songs aller Zeiten (Rolling Stone) \xe2\x80\x93 Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":[",\\t.",".\\t,"],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","Januar","Februar","M\xc3\xa4rz","April","Mai","Juni","Juli","August","September","Oktober","November","Dezember"],"wgRequestId":"78610108-1f8c-4741-983d-a4f58415eee3","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Die_500_besten_Songs_aller_Zeiten_(Rolling_Stone)","wgTitle":"Die 500 besten Songs aller Zeiten (Rolling Stone)","wgCurRevisionId":218052286,"wgRevisionId":218052286,"wgArticleId":976265,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Wikipedia:List
# ...

# %%
soup = BeautifulSoup(r.content, 'html.parser')

# %%
# get table with songs
pd.read_html('https://de.wikipedia.org/wiki/Die_500_besten_Songs_aller_Zeiten_(Rolling_Stone)')[0]
# Out:
#     Platzierung                                    Titel  \
#            2010 2004                               Titel
# 0             1    1                Like a Rolling Stone
# 1             2    2       (I Can’t Get No) Satisfaction
# 2             3    3                             Imagine
# 3             4    4                     What’s Going On
# 4             5    5                             Respect
# ..          ...  ...                                 ...
# 96           97   97                 Roll Over Beethoven
# 97           98   98                  Love and Happiness
# 98           99   99                       Fortunate Son
# 99          100    –                               Crazy
# 100         101  100  You Can’t Always Get What You Want
#
#                         Interpret VÖ-Datum  \
#                         Interpret VÖ-Datum
# 0                       Bob Dylan  1965/07
# 1              The Rolling Stones  1965/05
# 2                     John Lennon  1971/10
# ...
